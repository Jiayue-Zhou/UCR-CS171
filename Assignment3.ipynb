# %% [markdown]
# # Assignment 3
# ### Instructor: Vagelis Papalexakis
# ### Credit for  Assignment 3: 10/35 points of the final grade
#
# In this assignment we will implement the K-means clustering algorithm. We are going to use the same dataset as in the previous two assignments (<b>Note</b>: make sure you copy the dataset from Assignment 1 to the folder of this assignment!).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import random as rand
from sklearn.model_selection import train_test_split


data_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'label']
data = pd.read_csv('iris.data', 
                   names = data_names)

# %% [markdown]
# ## Question 1: Implementing and testing K-means clustering [100%]
# ### Question 1a: Implementing K-Means clustering [50%]
# In this question you should implement a function that performs k-means clustering, using the Euclidean distance (you may use Numpy libraries for the distance computation). For calculation of the centroid you should use the 'mean' function.
#
# For uniformity, you should implement a function with the following specifications:
# ```python
# def kmeans_clustering(all_vals,K,max_iter = 100, tol = pow(10,-3) ):
# ```
# where 1) 'all_vals' is the $N \times M$ matrix that contains all data points ($N$ is the number of data points and $M$ is the number of features, each row of the matrix is a data point), 2) 'K' is the number of clusters, 3) 'max_iter' is the maxium number of iterations, and 4) 'tol' is the tolerance for the change of the sum of squares of errors that determines convergence.
#
# Your function should return the following variables: 1) 'assignments': this is a $N\times 1$ vector (where $N$ is the number of data points) where the $i$-th position of that vector contains the cluster number that the $i$-th data point is assigned to, 2) 'centroids': this is a $K\times M$ matrix, each row of which contains the centroid for every cluster, 3) 'all_sse': this is a vector that contains all the sum of squares of errors per iteration of the algorithm, and 4) 'iters': this is the number of iterations that the algorithm ran.
#
# Here we are going to implement the simplest version of K-means, where the initial centroids are chosen entirely at random among all the data points.
#
# As we saw in class, the K-means algorithm iterates over the following steps:
# - Given a set of centroids, assign all data points to the cluster represented by its nearest centroid (according to Euclidean distance)
# - Given a set of assignments of points to clusters, compute the new centroids for every cluster, by taking the mean of all the points assigned to each cluster.
#
# Your algorithm should converge if 1) the maximum number of iteratiosn is reached, or 2) if the SSE between two consecutive iterations does not change a lot (as in the gradient descent for linear regression we saw in Assignment 2). In order to check for the latter condition, you may use the following piece of code:
# ```python
# if np.absolute(all_sse[it] - all_sse[it-1])/all_sse[it-1] <= tol
# ```
#
# In order to calculate the SSE (sum of squares of error) first you need to define what an 'error' is. In k-means, error per data point refers to the Euclidean distance of that particular point from its assigned centroid. SSE sums up all those squared Euclidean distances for all data points and comes up with a number that reflects the total error of approximating every data points by its assigned centroid.

# %%
import math
def calDistance(x1,x2):
    ssum = 0
    for i in range(4):
        ssum = ssum + (x1[data_names[i]]-x2[data_names[i]])**2
    ssum = math.sqrt(ssum)
    return ssum

# %%
def findNearest(centroids,point):
    mmin = 100000
    num = -1
    for i in range(centroids.shape[0]):
        Distance = calDistance(centroids.loc[i],point)
        if(Distance<mmin):
            mmin = Distance
            num = i
            #print(num)
    return num

# %%
def CalAve(data,temp):
    return data.loc[temp].mean()

# %%
def Update(data,assignment,K):
    newCentroids = pd.DataFrame(columns = data_names[0:4])
    for i in range(K):
        b = assignment[assignment['Cluster']==i] 
        #print(assignment)
        temp = b.index.tolist()
        tt = CalAve(data,temp)
        newCentroids.loc[i] = tt
    return newCentroids

# %%
def calErr(data,centroids,assignment,K): 
    sssum = 0
    for i in range(K): 
        b = assignment[assignment['Cluster']==i] 
        temp = b.index.tolist()
        for j in temp:
            sssum = sssum + calDistance(data.loc[j],centroids.loc[i])
    return sssum

# %%
#k-means clustering
import random
def kmeans_clustering(all_vals,K,max_iter = 100, tol = pow(10,-3) ):
    randomList = []
    all_sse = []
    centroids = pd.DataFrame(columns=data_names[0:4])
    a = np.zeros((150,1))
    assignment = pd.DataFrame(a,columns = [ 'Cluster'])
    for i in range(K):
        randomNum = random.randint(0,149)
        randomList.append(randomNum)
        centroids.loc[i] = all_vals.loc[randomNum]
    for i in range(150):
        point = all_vals.loc[i]
        CC = findNearest(centroids,point)
        assignment.loc[i]['Cluster'] = CC;
    err = calErr(all_vals,centroids,assignment,K)
    all_sse.append(err**2)
    for j in range(max_iter-1):
        for i in range(150):
            point = all_vals.loc[i]
            centroids = Update(all_vals,assignment,K)
            CC = findNearest(centroids,point)
            assignment.loc[i]['Cluster'] = CC
        err = calErr(all_vals,centroids,assignment,K)
        all_sse.append(err**2)
        if(np.absolute(all_sse[j+1] - all_sse[j])/all_sse[j] <= tol):
            break
    return assignment,centroids,all_sse,j+1

# %%
m1,m2,m3,m4 = kmeans_clustering(data,3)

# %%
m2
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0      5.901613     2.748387      4.393548     1.433871
# 1      5.006000     3.418000      1.464000     0.244000
# 2      6.850000     3.073684      5.742105     2.071053

# %%
m3
# Out:
# [42322.93300746571, 9595.893032744329, 9472.335528060714, 9472.335528060714]

# %%
m4
# Out:
# 3

# %% [markdown]
# ### Question 1b: Visualizing K-means [10%]
# In this question we wll visualize the result of the K-means algorithm. For ease of visualization, we will focus on a scatterplot of two of the four features of the Iris dataset. In particular: run your K-means code with K=3 and default values for the rest of the inputs. Subsequently, make a single scatterplot that contains all data points of the dataset for features 'sepal_length' and 'petal_length' and color every data point according to its cluster assignment.

# %%
#your code here
assignment,m2,m3,m4 = kmeans_clustering(data,3)

# %%
colors = ['b','g','r','orange']
for index in range(4):
    x = data.loc[assignment['Cluster'] == index]['sepal_length']
    y = data.loc[assignment['Cluster'] == index]['petal_length']
    plt.scatter(x, y, c=colors[index], cmap='brg', s=40, alpha=0.4, linewidth=0)  
plt.show()

# %% [markdown]
# ### Question 1c: Testing K-means [40%]
# Selecting the right number of clusters $K$ is a very challenging problem, especially when we don't have some side-information or domain expertise that can help us narrow down a few reasonable values for that parameter.
#
# In the absence of any other information, a very useful exercise is to create the plot of SSE (sum of squares of errors) as a function of $K$. Ideally, for a very small $K$, the error will be high (since we are trying to approximate a whole lot of points with a very small number of centroids) and as $K$ increases, the error decreases. However, after a certain value (or a couple of values) for $K$, we will notice diminishing returns, i.e., the error will be decreasing, but not to a great degree. Typically, the value(s) for $K$ where this behavior is observed (the threshold point after which we observe diminishing returns) is usually a good guess for the number of clusters.
#
# In this question, we will have to create the SSE vs. K plot for $K = 1\cdots10$. Furthermore, because K-means uses randomized initialization, we need to do a number of iterations per value of $K$ in order to get a good estimate of the actual SSE (which may not be caused by randomness in the initialization). For this question, you will have to run the entire K-means algorithm to completion, and repeat it 50 different times per $K$, and collect all SSEs. In the figure, you should report the mean SSE per $K$, surrounded by error-bars which will encode the standard deviation.

# %%
#your code here
accMatrix = np.zeros([10,50])
eee=[]
for i in range(10):
    ssum = 0
    for j in range(50):   
        m1,m2,m3,m4 = kmeans_clustering(data,i+1)
        accMatrix[i][j] = m3[len(m3)-1]
        print("Now ",i," row ",j," column...")
# Out:
# Now  0  row  0  column...
# Now  0  row  1  column...
# Now  0  row  2  column...
# Now  0  row  3  column...
# Now  0  row  4  column...
# Now  0  row  5  column...
# Now  0  row  6  column...
# Now  0  row  7  column...
# Now  0  row  8  column...
# Now  0  row  9  column...
# Now  0  row  10  column...
# Now  0  row  11  column...
# Now  0  row  12  column...
# Now  0  row  13  column...
# Now  0  row  14  column...
# Now  0  row  15  column...
# Now  0  row  16  column...
# Now  0  row  17  column...
# Now  0  row  18  column...
# Now  0  row  19  column...
# Now  0  row  20  column...
# Now  0  row  21  column...
# Now  0  row  22  column...
# Now  0  row  23  column...
# Now  0  row  24  column...
# Now  0  row  25  column...
# Now  0  row  26  column...
# Now  0  row  27  column...
# Now  0  row  28  column...
# Now  0  row  29  column...
# Now  0  row  30  column...
# Now  0  row  31  column...
# Now  0  row  32  column...
# Now  0  row  33  column...
# Now  0  row  34  column...
# Now  0  row  35  column...
# Now  0  row  36  column...
# Now  0  row  37  column...
# Now  0  row  38  column...
# Now  0  row  39  column...
# Now  0  row  40  column...
# Now  0  row  41  column...
# Now  0  row  42  column...
# Now  0  row  43  column...
# Now  0  row  44  column...
# Now  0  row  45  column...
# Now  0  row  46  column...
# Now  0  row  47  column...
# Now  0  row  48  column...
# Now  0  row  49  column...
# Now  1  row  0  column...
# Now  1  row  1  column...
# Now  1  row  2  column...
# Now  1  row  3  column...
# Now  1  row  4  column...
# Now  1  row  5  column...
# Now  1  row  6  column...
# Now  1  row  7  column...
# Now  1  row  8  column...
# Now  1  row  9  column...
# Now  1  row  10  column...
# Now  1  row  11  column...
# Now  1  row  12  column...
# Now  1  row  13  column...
# Now  1  row  14  column...
# Now  1  row  15  column...
# Now  1  row  16  column...
# Now  1  row  17  column...
# Now  1  row  18  column...
# Now  1  row  19  column...
# Now  1  row  20  column...
# Now  1  row  21  column...
# Now  1  row  22  column...
# Now  1  row  23  column...
# Now  1  row  24  column...
# Now  1  row  25  column...
# Now  1  row  26  column...
# Now  1  row  27  column...
# Now  1  row  28  column...
# Now  1  row  29  column...
# Now  1  row  30  column...
# Now  1  row  31  column...
# Now  1  row  32  column...
# Now  1  row  33  column...
# Now  1  row  34  column...
# Now  1  row  35  column...
# Now  1  row  36  column...
# Now  1  row  37  column...
# Now  1  row  38  column...
# Now  1  row  39  column...
# Now  1  row  40  column...
# Now  1  row  41  column...
# Now  1  row  42  column...
# Now  1  row  43  column...
# Now  1  row  44  column...
# Now  1  row  45  column...
# Now  1  row  46  column...
# Now  1  row  47  column...
# Now  1  row  48  column...
# Now  1  row  49  column...
# Now  2  row  0  column...
# Now  2  row  1  column...
# Now  2  row  2  column...
# Now  2  row  3  column...
# Now  2  row  4  column...
# Now  2  row  5  column...
# Now  2  row  6  column...
# Now  2  row  7  column...
# Now  2  row  8  column...
# Now  2  row  9  column...
# Now  2  row  10  column...
# Now  2  row  11  column...
# Now  2  row  12  column...
# Now  2  row  13  column...
# Now  2  row  14  column...
# Now  2  row  15  column...
# Now  2  row  16  column...
# Now  2  row  17  column...
# Now  2  row  18  column...
# Now  2  row  19  column...
# Now  2  row  20  column...
# Now  2  row  21  column...
# Now  2  row  22  column...
# Now  2  row  23  column...
# Now  2  row  24  column...
# Now  2  row  25  column...
# Now  2  row  26  column...
# Now  2  row  27  column...
# Now  2  row  28  column...
# Now  2  row  29  column...
# Now  2  row  30  column...
# Now  2  row  31  column...
# Now  2  row  32  column...
# Now  2  row  33  column...
# Now  2  row  34  column...
# Now  2  row  35  column...
# Now  2  row  36  column...
# Now  2  row  37  column...
# Now  2  row  38  column...
# Now  2  row  39  column...
# Now  2  row  40  column...
# Now  2  row  41  column...
# Now  2  row  42  column...
# Now  2  row  43  column...
# Now  2  row  44  column...
# Now  2  row  45  column...
# Now  2  row  46  column...
# Now  2  row  47  column...
# Now  2  row  48  column...
# Now  2  row  49  column...
# Now  3  row  0  column...
# Now  3  row  1  column...
# Now  3  row  2  column...
# Now  3  row  3  column...
# Now  3  row  4  column...
# Now  3  row  5  column...
# Now  3  row  6  column...
# Now  3  row  7  column...
# Now  3  row  8  column...
# Now  3  row  9  column...
# Now  3  row  10  column...
# Now  3  row  11  column...
# Now  3  row  12  column...
# Now  3  row  13  column...
# Now  3  row  14  column...
# Now  3  row  15  column...
# Now  3  row  16  column...
# Now  3  row  17  column...
# Now  3  row  18  column...
# Now  3  row  19  column...
# Now  3  row  20  column...
# Now  3  row  21  column...
# Now  3  row  22  column...
# Now  3  row  23  column...
# Now  3  row  24  column...
# Now  3  row  25  column...
# Now  3  row  26  column...
# Now  3  row  27  column...
# Now  3  row  28  column...
# Now  3  row  29  column...
# Now  3  row  30  column...
# Now  3  row  31  column...
# Now  3  row  32  column...
# Now  3  row  33  column...
# Now  3  row  34  column...
# Now  3  row  35  column...
# Now  3  row  36  column...
# Now  3  row  37  column...
# Now  3  row  38  column...
# Now  3  row  39  column...
# Now  3  row  40  column...
# Now  3  row  41  column...
# Now  3  row  42  column...
# Now  3  row  43  column...
# Now  3  row  44  column...
# Now  3  row  45  column...
# Now  3  row  46  column...
# Now  3  row  47  column...
# Now  3  row  48  column...
# Now  3  row  49  column...
# Now  4  row  0  column...
# Now  4  row  1  column...
# Now  4  row  2  column...
# Now  4  row  3  column...
# Now  4  row  4  column...
# Now  4  row  5  column...
# Now  4  row  6  column...
# Now  4  row  7  column...
# Now  4  row  8  column...
# Now  4  row  9  column...
# Now  4  row  10  column...
# Now  4  row  11  column...
# Now  4  row  12  column...
# Now  4  row  13  column...
# Now  4  row  14  column...
# Now  4  row  15  column...
# Now  4  row  16  column...
# Now  4  row  17  column...
# Now  4  row  18  column...
# Now  4  row  19  column...
# Now  4  row  20  column...
# Now  4  row  21  column...
# Now  4  row  22  column...
# Now  4  row  23  column...
# Now  4  row  24  column...
# Now  4  row  25  column...
# Now  4  row  26  column...
# Now  4  row  27  column...
# Now  4  row  28  column...
# Now  4  row  29  column...
# Now  4  row  30  column...
# Now  4  row  31  column...
# Now  4  row  32  column...
# Now  4  row  33  column...
# Now  4  row  34  column...
# Now  4  row  35  column...
# Now  4  row  36  column...
# Now  4  row  37  column...
# Now  4  row  38  column...
# Now  4  row  39  column...
# Now  4  row  40  column...
# Now  4  row  41  column...
# Now  4  row  42  column...
# Now  4  row  43  column...
# Now  4  row  44  column...
# Now  4  row  45  column...
# Now  4  row  46  column...
# Now  4  row  47  column...
# Now  4  row  48  column...
# Now  4  row  49  column...
# Now  5  row  0  column...
# Now  5  row  1  column...
# Now  5  row  2  column...
# Now  5  row  3  column...
# Now  5  row  4  column...
# Now  5  row  5  column...
# Now  5  row  6  column...
# Now  5  row  7  column...
# Now  5  row  8  column...
# Now  5  row  9  column...
# Now  5  row  10  column...
# Now  5  row  11  column...
# Now  5  row  12  column...
# Now  5  row  13  column...
# Now  5  row  14  column...
# Now  5  row  15  column...
# Now  5  row  16  column...
# Now  5  row  17  column...
# Now  5  row  18  column...
# Now  5  row  19  column...
# Now  5  row  20  column...
# Now  5  row  21  column...
# Now  5  row  22  column...
# Now  5  row  23  column...
# Now  5  row  24  column...
# Now  5  row  25  column...
# Now  5  row  26  column...
# Now  5  row  27  column...
# Now  5  row  28  column...
# Now  5  row  29  column...
# Now  5  row  30  column...
# Now  5  row  31  column...
# Now  5  row  32  column...
# Now  5  row  33  column...
# Now  5  row  34  column...
# Now  5  row  35  column...
# Now  5  row  36  column...
# Now  5  row  37  column...
# Now  5  row  38  column...
# Now  5  row  39  column...
# Now  5  row  40  column...
# Now  5  row  41  column...
# Now  5  row  42  column...
# Now  5  row  43  column...
# Now  5  row  44  column...
# Now  5  row  45  column...
# Now  5  row  46  column...
# Now  5  row  47  column...
# Now  5  row  48  column...
# Now  5  row  49  column...
# Now  6  row  0  column...
# Now  6  row  1  column...
# Now  6  row  2  column...
# Now  6  row  3  column...
# Now  6  row  4  column...
# Now  6  row  5  column...
# Now  6  row  6  column...
# Now  6  row  7  column...
# Now  6  row  8  column...
# Now  6  row  9  column...
# Now  6  row  10  column...
# Now  6  row  11  column...
# Now  6  row  12  column...
# Now  6  row  13  column...
# Now  6  row  14  column...
# Now  6  row  15  column...
# Now  6  row  16  column...
# Now  6  row  17  column...
# Now  6  row  18  column...
# Now  6  row  19  column...
# Now  6  row  20  column...
# Now  6  row  21  column...
# Now  6  row  22  column...
# Now  6  row  23  column...
# Now  6  row  24  column...
# Now  6  row  25  column...
# Now  6  row  26  column...
# Now  6  row  27  column...
# Now  6  row  28  column...
# Now  6  row  29  column...
# Now  6  row  30  column...
# Now  6  row  31  column...
# Now  6  row  32  column...
# Now  6  row  33  column...
# Now  6  row  34  column...
# Now  6  row  35  column...
# Now  6  row  36  column...
# Now  6  row  37  column...
# Now  6  row  38  column...
# Now  6  row  39  column...
# Now  6  row  40  column...
# Now  6  row  41  column...
# Now  6  row  42  column...
# Now  6  row  43  column...
# Now  6  row  44  column...
# Now  6  row  45  column...
# Now  6  row  46  column...
# Now  6  row  47  column...
# Now  6  row  48  column...
# Now  6  row  49  column...
# Now  7  row  0  column...
# Now  7  row  1  column...
# Now  7  row  2  column...
# Now  7  row  3  column...
# Now  7  row  4  column...
# Now  7  row  5  column...
# Now  7  row  6  column...
# Now  7  row  7  column...
# Now  7  row  8  column...
# Now  7  row  9  column...
# Now  7  row  10  column...
# Now  7  row  11  column...
# Now  7  row  12  column...
# Now  7  row  13  column...
# Now  7  row  14  column...
# Now  7  row  15  column...
# Now  7  row  16  column...
# Now  7  row  17  column...
# Now  7  row  18  column...
# Now  7  row  19  column...
# Now  7  row  20  column...
# Now  7  row  21  column...
# Now  7  row  22  column...
# Now  7  row  23  column...
# Now  7  row  24  column...
# Now  7  row  25  column...
# Now  7  row  26  column...
# Now  7  row  27  column...
# Now  7  row  28  column...
# Now  7  row  29  column...
# Now  7  row  30  column...
# Now  7  row  31  column...
# Now  7  row  32  column...
# Now  7  row  33  column...
# Now  7  row  34  column...
# Now  7  row  35  column...
# Now  7  row  36  column...
# Now  7  row  37  column...
# Now  7  row  38  column...
# Now  7  row  39  column...
# Now  7  row  40  column...
# Now  7  row  41  column...
# Now  7  row  42  column...
# Now  7  row  43  column...
# Now  7  row  44  column...
# Now  7  row  45  column...
# Now  7  row  46  column...
# Now  7  row  47  column...
# Now  7  row  48  column...
# Now  7  row  49  column...
# Now  8  row  0  column...
# Now  8  row  1  column...
# Now  8  row  2  column...
# Now  8  row  3  column...
# Now  8  row  4  column...
# Now  8  row  5  column...
# Now  8  row  6  column...
# Now  8  row  7  column...
# Now  8  row  8  column...
# Now  8  row  9  column...
# Now  8  row  10  column...
# Now  8  row  11  column...
# Now  8  row  12  column...
# Now  8  row  13  column...
# Now  8  row  14  column...
# Now  8  row  15  column...
# Now  8  row  16  column...
# Now  8  row  17  column...
# Now  8  row  18  column...
# Now  8  row  19  column...
# Now  8  row  20  column...
# Now  8  row  21  column...
# Now  8  row  22  column...
# Now  8  row  23  column...
# Now  8  row  24  column...
# Now  8  row  25  column...
# Now  8  row  26  column...
# Now  8  row  27  column...
# Now  8  row  28  column...
# Now  8  row  29  column...
# Now  8  row  30  column...
# Now  8  row  31  column...
# Now  8  row  32  column...
# Now  8  row  33  column...
# Now  8  row  34  column...
# Now  8  row  35  column...
# Now  8  row  36  column...
# Now  8  row  37  column...
# Now  8  row  38  column...
# Now  8  row  39  column...
# Now  8  row  40  column...
# Now  8  row  41  column...
# Now  8  row  42  column...
# Now  8  row  43  column...
# Now  8  row  44  column...
# Now  8  row  45  column...
# Now  8  row  46  column...
# Now  8  row  47  column...
# Now  8  row  48  column...
# Now  8  row  49  column...
# Now  9  row  0  column...
# Now  9  row  1  column...
# Now  9  row  2  column...
# Now  9  row  3  column...
# Now  9  row  4  column...
# Now  9  row  5  column...
# Now  9  row  6  column...
# Now  9  row  7  column...
# Now  9  row  8  column...
# Now  9  row  9  column...
# Now  9  row  10  column...
# Now  9  row  11  column...
# Now  9  row  12  column...
# Now  9  row  13  column...
# Now  9  row  14  column...
# Now  9  row  15  column...
# Now  9  row  16  column...
# Now  9  row  17  column...
# Now  9  row  18  column...
# Now  9  row  19  column...
# Now  9  row  20  column...
# Now  9  row  21  column...
# Now  9  row  22  column...
# Now  9  row  23  column...
# Now  9  row  24  column...
# Now  9  row  25  column...
# Now  9  row  26  column...
# Now  9  row  27  column...
# Now  9  row  28  column...
# Now  9  row  29  column...
# Now  9  row  30  column...
# Now  9  row  31  column...
# Now  9  row  32  column...
# Now  9  row  33  column...
# Now  9  row  34  column...
# Now  9  row  35  column...
# Now  9  row  36  column...
# Now  9  row  37  column...
# Now  9  row  38  column...
# Now  9  row  39  column...
# Now  9  row  40  column...
# Now  9  row  41  column...
# Now  9  row  42  column...
# Now  9  row  43  column...
# Now  9  row  44  column...
# Now  9  row  45  column...
# Now  9  row  46  column...
# Now  9  row  47  column...
# Now  9  row  48  column...
# Now  9  row  49  column...

# %%
accMatrix
# Out:
# array([[84946.08922425, 84946.08922425, 84946.08922425, 84946.08922425,
#         84946.08922425, 84946.08922425, 84946.08922425, 84946.08922425,
#         84946.08922425, 84946.08922425, 84946.08922425, 84946.08922425,
#         84946.08922425, 84946.08922425, 84946.08922425, 84946.08922425,
#         84946.08922425, 84946.08922425, 84946.08922425, 84946.08922425,
#         84946.08922425, 84946.08922425, 84946.08922425, 84946.08922425,
#         84946.08922425, 84946.08922425, 84946.08922425, 84946.08922425,
#         84946.08922425, 84946.08922425, 84946.08922425, 84946.08922425,
#         84946.08922425, 84946.08922425, 84946.08922425, 84946.08922425,
#         84946.08922425, 84946.08922425, 84946.08922425, 84946.08922425,
#         84946.08922425, 84946.08922425, 84946.08922425, 84946.08922425,
#         84946.08922425, 84946.08922425, 84946.08922425, 84946.08922425,
#         84946.08922425, 84946.08922425],
#        [16487.63735523, 16487.63735523, 16487.63735523, 16487.63735523,
#         16487.63735523, 16487.63735523, 16487.63735523, 16487.63735523,
#         16487.63735523, 16487.63735523, 16487.63735523, 16487.63735523,
#         16487.63735523, 16487.63735523, 16487.63735523, 16487.63735523,
#         16487.63735523, 16487.63735523, 16487.63735523, 16487.63735523,
#         16487.63735523, 16487.63735523, 16487.63735523, 16487.63735523,
#         16487.63735523, 16487.63735523, 16487.63735523, 16487.63735523,
#         16487.63735523, 16487.63735523, 16487.63735523, 16487.63735523,
#         16487.63735523, 16487.63735523, 16487.63735523, 16487.63735523,
#         16487.63735523, 16487.63735523, 16487.63735523, 16487.63735523,
#         16487.63735523, 16487.63735523, 16487.63735523, 16487.63735523,
#         16487.63735523, 16487.63735523, 16487.63735523, 16487.63735523,
#         16487.63735523, 16487.63735523],
#        [ 9472.33552722,  9472.33552722, 14952.12534512, 15001.03338179,
#          9475.9874174 ,  9472.33552722,  9472.33552722,  9475.9874174 ,
#          9472.33552722, 15338.75934152,  9472.33552722,  9472.33552722,
#         15338.75934152,  9454.10868794, 15001.03338179, 15338.75934152,
#          9475.9874174 ,  9472.33552722,  9472.33552722,  9472.33552722,
#         15338.75934152,  9475.9874174 ,  9475.9874174 , 14952.12534512,
#          9476.28648793,  9472.33552722,  9472.33552722, 14952.12534512,
#          9475.9874174 ,  9476.28648793,  9476.28648793, 15001.03338179,
#          9472.33552722,  9476.28648793,  9472.33552722, 14952.12534512,
#         14952.12534512,  9472.33552722, 15338.75934152,  9475.9874174 ,
#          9472.33552722, 15338.75934152,  9476.28648793, 15338.75934152,
#         15301.89752477,  9475.9874174 , 14952.12534512,  9472.33552722,
#          9476.28648793,  9475.9874174 ],
#        [ 7170.26298528,  8227.132203  ,  7170.26298528,  8232.8695651 ,
#          7020.1270507 ,  7010.55658868,  7170.26298528,  8229.18695331,
#          7170.26298528,  7020.1270507 ,  8226.85353869,  7103.62375861,
#          8226.85353869,  8354.30266394,  7028.87707981,  7010.55658868,
#          7170.26298528,  8232.8695651 ,  8223.45087476,  9475.9874174 ,
#          7170.26298528,  7020.1270507 ,  7126.26502846,  7010.55658868,
#          8229.18695331,  7020.1270507 ,  8223.45087476,  7020.1270507 ,
#          7010.55658868,  7020.1270507 ,  7010.55658868,  7170.26298528,
#          7020.1270507 ,  8227.132203  ,  8354.30266394,  7170.26298528,
#          8229.18695331,  7126.26502846,  7170.26298528,  8354.30266394,
#          8232.59080545,  9475.9874174 ,  7020.1270507 ,  7170.26298528,
#          7174.96699027,  7020.1270507 ,  9472.33552722,  8354.30266394,
#          7020.1270507 ,  9472.33552722],
#        [ 7170.26298528,  6089.41844473,  5951.12251445,  6089.41844473,
#          8226.85353869,  5842.739085  ,  5842.739085  ,  6199.13666082,
#          6190.52626274,  5995.67670871,  7808.06353702,  7807.10808562,
#          7985.06797396,  5862.83931515,  7808.22872238,  5942.31106996,
#          6050.70185897,  7874.7655783 ,  5870.83127735,  5956.00230193,
#          7806.20549925,  5942.31106996,  6199.13666082,  7918.72888638,
#          6137.18521099,  5842.739085  ,  7938.44352346,  5862.83931515,
#          6089.41844473,  7809.40706079,  7938.44352346,  7170.26298528,
#          5842.739085  ,  6190.52626274,  6089.41844473,  6089.41844473,
#          7802.80315538,  5870.83127735,  8354.58347662,  5842.739085  ,
#          5870.83127735,  7010.55658868,  6059.59327328,  5842.739085  ,
#          5870.83127735,  6094.35459325,  5857.49523141,  5951.12251445,
#          6158.23131097,  6443.72252741],
#        [ 5234.89958197,  4871.36050255,  5164.30782067,  5870.83127735,
#          5519.54001284,  5597.75038153,  5595.89234106,  4871.36050255,
#          5588.33378814,  4969.545424  ,  4969.545424  ,  5290.68402891,
#          5184.30576403,  4894.13882117,  5423.87519742,  4894.13882117,
#          5178.73831725,  5942.31106996,  5236.55734902,  4875.77555602,
#          4901.44098593,  7644.98679141,  5164.30782067,  5670.46603034,
#          5381.92308834,  5287.18272345,  6056.81494712,  6053.7969965 ,
#          5641.66700342,  7542.04956812,  5760.04274789,  5870.83127735,
#          4875.77555602,  5734.57442308,  5234.89958197,  5409.64891898,
#          6042.13834499,  5730.02130395,  5842.739085  ,  4871.36050255,
#          5587.34802338,  5230.16535853,  5164.30782067,  5527.61539118,
#          7551.38113668,  5268.08228009,  5665.2487047 ,  5689.26533289,
#          5951.12251445,  5688.8945523 ],
#        [ 7441.72985989,  4253.70568031,  4257.83141646,  4321.95111897,
#          5044.37585814,  4982.53069313,  5601.04153195,  4737.86880532,
#          4555.22762541,  5191.27883149,  4785.66783831,  4719.48487777,
#          4301.04816904,  5663.69300105,  4487.55147503,  5595.89234106,
#          4271.85689646,  4654.1729067 ,  5803.63854019,  5215.50750591,
#          5362.53877789,  5188.02987263,  4601.31646422,  4301.04816904,
#          5842.739085  ,  5127.34953925,  4440.72260306,  4685.23394065,
#          4995.49065473,  5152.508092  ,  5035.29552081,  5164.30782067,
#          5234.89958197,  4487.55147503,  4601.31646422,  5186.72313976,
#          4676.04852497,  7478.40471109,  5164.30782067,  4358.7251965 ,
#          4719.463088  ,  4754.12197288,  4253.70568031,  4317.36620521,
#          4345.53032975,  4275.99142368,  5076.67367056,  4313.29933979,
#          4694.47835441,  5551.44128912],
#        [ 4407.36654533,  4788.81154972,  3972.56526217,  4402.88241493,
#          3932.33362548,  4439.62590363,  4236.67380285,  5082.76582003,
#          3850.90605504,  5279.00091272,  4472.94583114,  5361.78901604,
#          4438.70734951,  4398.589472  ,  4633.79508466,  3938.25773292,
#          4257.86410128,  4879.40764094,  4362.97710401,  5302.94990861,
#          4380.81811636,  4576.18642909,  4098.93771824,  4402.74169601,
#          5399.96221225,  4838.96895165,  4396.04491902,  4576.17646056,
#          3812.80749652,  4530.50042963,  4557.33628824,  4445.86318743,
#          5468.48331691,  4815.34123551,  4215.11901612,  5214.06459258,
#          4476.02478024,  3818.26936413,  3834.52684713,  5824.50210438,
#          4676.04852497,  4145.56114375,  4557.09060277,  4605.73727178,
#          4437.45706803,  4117.49693938,  4152.6652403 ,  4486.02912746,
#          4440.69955142,  5280.04957728],
#        [ 3566.82679588,  3538.36049648,  3635.14349632,  4305.2252993 ,
#          3572.08864222,  3897.79071977,  3841.84617503,  4289.63342349,
#          3993.27468718,  4159.56680277,  5343.35472761,  4355.34762103,
#          3796.22142171,  3534.05353967,  3816.62787774,  4315.18875322,
#          3976.38935326,  3648.29848039,  4176.48718694,  5330.9433583 ,
#          3561.39364386,  7297.79804084,  4482.76617823,  4388.07106909,
#          4353.52770181,  4162.72862935,  4300.89313763,  4440.83875516,
#          3756.4864954 ,  4705.46727968,  4081.82712813,  3993.92038503,
#          4772.80363526,  4328.89286008,  4295.74773152,  3986.75981012,
#          3809.23216143,  4169.41720498,  3631.28167072,  4438.87230714,
#          3875.037112  ,  3669.67859664,  3926.25833719,  4246.78099838,
#          4093.01900274,  4259.91530279,  3609.10730866,  3906.49444007,
#          4385.98820776,  4364.06662636],
#        [ 3595.13892888,  3651.48559997,  3740.30386901,  3750.43479831,
#          3546.85657376,  3736.24700513,  3579.94710934,  3581.17902855,
#          3668.38932565,  4269.24741014,  4291.54565506,  4208.90254221,
#          3410.90267995,  3725.80693869,  3658.07661701,  5167.86387766,
#          3550.01276614,  3834.68973878,  3499.64787302,  3437.01523708,
#          3472.1366005 ,  3261.29181609,  4203.58536569,  4273.10108314,
#          3413.15481875,  3536.59958238,  3505.46022728,  3623.47812461,
#          3384.43393644,  3423.76881678,  4032.57321513,  3850.71299607,
#          3775.1112598 ,  3950.03586552,  3934.8681435 ,  3617.85857145,
#          3658.26769919,  3582.13742729,  4078.62419612,  3631.51647204,
#          3670.83773307,  3434.86264933,  3714.24447515,  3771.62542557,
#          3457.17748298,  3487.81567473,  3487.30059339,  3934.33969724,
#          3333.53303382,  3613.22904743]])

# %%
accMatrix_mean = np.zeros(10)
accMatrix_std = np.zeros(10)
for i in range(10):
    #print(i)
    accMatrix_mean[i] = np.mean(accMatrix[i])
    accMatrix_std[i] = np.std(accMatrix[i])

# %%
x = np.linspace(1,10,10)
plt.errorbar(x, accMatrix_mean, yerr=accMatrix_std, fmt='bo:',color='b',elinewidth=2,capsize=4)
plt.show()
